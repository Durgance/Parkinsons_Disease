# %% [markdown]
# <img src="https://media.giphy.com/media/ejM13zJWlRz1e/giphy.gif" width=50%>

# %% [markdown]
# # Parkinsons Disease  Biomedical Voice Measurements📏

# %% [markdown]
# ## About Parkinson's
# -  Parkinson's disease is a brain disorder that leads to shaking, stiffness, and difficulty with walking, balance, and coordination. Older woman and her caregiver
#
# -  Parkinson's symptoms usually begin gradually and get worse over time. As the disease progresses, people may have difficulty walking and talking. They may also have mental and behavioral changes, sleep problems, depression, memory difficulties, and fatigue.
#
# -  Both men and women can have Parkinson’s disease. However, the disease affects about 50 percent more men than women.
#
# -  One clear risk factor for Parkinson's is age. Although most people with Parkinson’s first develop the disease at about age 60, about 5 to 10 percent of people with Parkinson's have "early-onset" disease, which begins before the age of 50. Early-onset forms of Parkinson's are often, but not always, inherited, and some forms have been linked to specific gene mutations.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Getting and Formatting the data

# %%
df=pd.read_csv("./Parkinsons disease raw data.txt",header= None)

# %% [markdown]
# ## As the data is in text format, We need to process the data into a DataFrame.
# <img src="https://media.giphy.com/media/xT9C25UNTwfZuk85WP/giphy.gif">
#
# ## By using **Try except** block we can make our model more dynamic , As it can inculcate more data if we need to add to our models without changing any parameters.🔥🔥

# %%
start=(df[1:24]).transpose()

# %%
i=1+24
j=24+24
try :
    while True:
        add=df[i:j].transpose()
        add.columns=range(1,24)
        start=pd.concat([start,add])
        
        i=i+24
        j=j+24
        
except:
    print("Got all the data😁")
# Out:
# Got all the data😁

# %%
start.head()
# Out:
#         1        2        3        4        5                      6   \
# 0  119.992  157.302   74.997  0.00784    7e-05                 0.0037
# 0    122.4   148.65  113.819  0.00968    8e-05                0.00465
# 0  116.682  131.111  111.555   0.0105    9e-05  0.0054399999999999995
# 0  116.676  137.871  111.366  0.00997    9e-05                0.00502
# 0  116.014  141.781  110.655  0.01284  0.00011                0.00655
#
#                      7                     8                     9      10  \
# 0               0.00554  0.011090000000000001               0.04374  0.426
# 0  0.006959999999999999  0.013940000000000001               0.06134  0.626
# 0  0.007809999999999999               0.01633  0.052329999999999995  0.482
# 0               0.00698               0.01505  0.054920000000000004  0.517
# 0               0.00908               0.01966               0.06425  0.584
#
#    ...                   14                    15      16 17  \
# ...

# %%
start.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 0
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       195 non-null    object
#  1   2       195 non-null    object
#  2   3       195 non-null    object
#  3   4       195 non-null    object
#  4   5       195 non-null    object
#  5   6       195 non-null    object
#  6   7       195 non-null    object
#  7   8       195 non-null    object
#  8   9       195 non-null    object
#  9   10      195 non-null    object
#  10  11      195 non-null    object
#  11  12      195 non-null    object
#  12  13      195 non-null    object
#  13  14      195 non-null    object
#  14  15      195 non-null    object
#  15  16      195 non-null    object
#  16  17      195 non-null    object
#  17  18      195 non-null    object
#  18  19      195 non-null    object
#  19  20      195 non-null    object
#  20  21      195 non-null    object
# ...

# %% [markdown]
# ## Creating the column names (i don't like index as column name) to get the difference betweem Target and feature easily😊

# %%
start.columns=['feature 1',
'feature 2',
'feature 3',
'feature 4',
'feature 5',
'feature 6',
'feature 7',
'feature 8',
'feature 9',
'feature 10',
'feature 11',
'feature 12',
'feature 13',
'feature 14',
'feature 15',
'feature 16',
'Target',
'feature 18',
'feature 19',
'feature 20',
'feature 21',
'feature 22',
'feature 23',]

# %%
start.shape
# Out:
# (195, 23)

# %%
start.head()
# Out:
#   feature 1 feature 2 feature 3 feature 4 feature 5              feature 6  \
# 0   119.992   157.302    74.997   0.00784     7e-05                 0.0037
# 0     122.4    148.65   113.819   0.00968     8e-05                0.00465
# 0   116.682   131.111   111.555    0.0105     9e-05  0.0054399999999999995
# 0   116.676   137.871   111.366   0.00997     9e-05                0.00502
# 0   116.014   141.781   110.655   0.01284   0.00011                0.00655
#
#               feature 7             feature 8             feature 9  \
# 0               0.00554  0.011090000000000001               0.04374
# 0  0.006959999999999999  0.013940000000000001               0.06134
# 0  0.007809999999999999               0.01633  0.052329999999999995
# 0               0.00698               0.01505  0.054920000000000004
# 0               0.00908               0.01966               0.06425
#
#   feature 10  ...           feature 14            feature 15 feature 16  \
# ...

# %%
df=start

# %%
df.head()
# Out:
#   feature 1 feature 2 feature 3 feature 4 feature 5              feature 6  \
# 0   119.992   157.302    74.997   0.00784     7e-05                 0.0037
# 0     122.4    148.65   113.819   0.00968     8e-05                0.00465
# 0   116.682   131.111   111.555    0.0105     9e-05  0.0054399999999999995
# 0   116.676   137.871   111.366   0.00997     9e-05                0.00502
# 0   116.014   141.781   110.655   0.01284   0.00011                0.00655
#
#               feature 7             feature 8             feature 9  \
# 0               0.00554  0.011090000000000001               0.04374
# 0  0.006959999999999999  0.013940000000000001               0.06134
# 0  0.007809999999999999               0.01633  0.052329999999999995
# 0               0.00698               0.01505  0.054920000000000004
# 0               0.00908               0.01966               0.06425
#
#   feature 10  ...           feature 14            feature 15 feature 16  \
# ...

# %%
feature_col=['feature 1',
'feature 2',
'feature 3',
'feature 4',
'feature 5',
'feature 6',
'feature 7',
'feature 8',
'feature 9',
'feature 10',
'feature 11',
'feature 12',
'feature 13',
'feature 14',
'feature 15',
'feature 16',
'feature 18',
'feature 19',
'feature 20',
'feature 21',
'feature 22',
'feature 23']

# %%
df=df.loc[:,feature_col].astype(float)

# %%
df.dtypes
# Out:
# feature 1     float64
# feature 2     float64
# feature 3     float64
# feature 4     float64
# feature 5     float64
# feature 6     float64
# feature 7     float64
# feature 8     float64
# feature 9     float64
# feature 10    float64
# feature 11    float64
# feature 12    float64
# feature 13    float64
# feature 14    float64
# feature 15    float64
# feature 16    float64
# feature 18    float64
# feature 19    float64
# feature 20    float64
# feature 21    float64
# feature 22    float64
# feature 23    float64
# dtype: object

# %%
df=pd.concat([df,start["Target"]],axis=1)

# %%
df.Target=df.Target.astype(int)

# %%
df.isnull().sum()
# Out:
# feature 1     0
# feature 2     0
# feature 3     0
# feature 4     0
# feature 5     0
# feature 6     0
# feature 7     0
# feature 8     0
# feature 9     0
# feature 10    0
# feature 11    0
# feature 12    0
# feature 13    0
# feature 14    0
# feature 15    0
# feature 16    0
# feature 18    0
# feature 19    0
# feature 20    0
# feature 21    0
# feature 22    0
# feature 23    0
# Target        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 0
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   feature 1   195 non-null    float64
#  1   feature 2   195 non-null    float64
#  2   feature 3   195 non-null    float64
#  3   feature 4   195 non-null    float64
#  4   feature 5   195 non-null    float64
#  5   feature 6   195 non-null    float64
#  6   feature 7   195 non-null    float64
#  7   feature 8   195 non-null    float64
#  8   feature 9   195 non-null    float64
#  9   feature 10  195 non-null    float64
#  10  feature 11  195 non-null    float64
#  11  feature 12  195 non-null    float64
#  12  feature 13  195 non-null    float64
#  13  feature 14  195 non-null    float64
#  14  feature 15  195 non-null    float64
#  15  feature 16  195 non-null    float64
#  16  feature 18  195 non-null    float64
#  17  feature 19  195 non-null    float64
# ...

# %% [markdown]
# ## Now we have got the Data in the format we require for working on it
# <img src="https://media.giphy.com/media/K3RxMSrERT8iI/giphy.gif" width=30%>

# %% [markdown]
# # EDA

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.style.use('ggplot')

# %% [markdown]
# ## Getting the relationship of different features with respect to Target Variable.

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Checking the distribution of Target variable for Imbalance 📊

# %%
plt.figure(figsize=(10,5))
sns.countplot(df.Target)
# Out:
# <AxesSubplot:xlabel='Target', ylabel='count'>

# %% [markdown]
# ## As we can see our data is having imbalance so we need to use few methods to work on such data.
# *  First : We can use Stratified KFold Cross Validation for getting equal amount of data in the test and train split
# *  Second : Using AUC score as it is the best evaludation matrix for Skewed Binary Classification

# %% [markdown]
# ## Checking the Distrubution of the Featured Data i.e. Checking for Skewness📈📉

# %%
# The red line in the plot represents the mean of the data

plt.figure(figsize=(15,10))
for i,col in enumerate(df.columns,1):
    plt.subplot(6,4,i)
    sns.histplot(df[col],kde=True)
    plt.axvline(x=df[col].mean(),
            color='red')
    plt.tight_layout()

# %% [markdown]
# ## Here the Plot shows the Distribution of data as well as the median of the data.
# ## For checking the type of skewness in the data i.e.
# *  Left Skewed Data
# *  Right Skewed Data
#
#
# <img src="https://media.giphy.com/media/OSUuEuaz0imBy/giphy.gif">

# %% [markdown]
# # Checking for Outliers in the data

# %%
def outlier_function(df, col_name):
    first_quartile = np.percentile(np.array(df[col_name].tolist()), 25)
    third_quartile = np.percentile(np.array(df[col_name].tolist()), 75)
    IQR = third_quartile - first_quartile
    
    upper_limit = third_quartile+(3*IQR)
    lower_limit = first_quartile-(3*IQR)
    outlier_count = 0
    
    for value in df[col_name].tolist():
        if (value < lower_limit) | (value > upper_limit):
            outlier_count += 1
    return lower_limit, upper_limit, outlier_count

# %%
plt.figure(figsize=(30,20))
try:
    for i,col in enumerate(df.columns,1):
        plt.subplot(4,6,i)
        sns.boxplot(y=feature_col[i],x="Target",data=df)
        plt.tight_layout()
        out=outlier_function(df,col)
        if out[2]>0:
            print(f"There are {out[2]} outliers in {col}")
except:
    pass
# Out:
# There are 6 outliers in feature 2
# There are 5 outliers in feature 4
# There are 2 outliers in feature 5
# There are 7 outliers in feature 6
# There are 6 outliers in feature 7
# There are 7 outliers in feature 8
# There are 1 outliers in feature 9
# There are 2 outliers in feature 10
# There are 1 outliers in feature 11
# There are 1 outliers in feature 12
# There are 3 outliers in feature 13
# There are 1 outliers in feature 14
# There are 11 outliers in feature 15

# %% [markdown]
# ## There are not many outliers in each feature as the we can see.
# ## We can use Scaling techniques for working with outliers
# <img src="https://media.giphy.com/media/fnHxVS8gD2Z0SBFuYn/giphy.gif">

# %% [markdown]
# # Feature Selection
# - 👉 The simplest form of feature selection can be to remove all the features with very low variance.
# - 👉 But the variance also depends on scaling of the data
# - 👉 We can also fit the model to the data and select features from the model by feature coefficients or by the importance of the feature
# ## To avoide the curse of dimentionality

# %%
from sklearn.ensemble import RandomForestClassifier
X = df[feature_col]
y = df["Target"]
model = RandomForestClassifier()
model.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
plt.figure(figsize=(15,10))
importance = model.feature_importances_
idxs = np.argsort(importance)
plt.title("Feature Importance")
plt.barh(range(len(idxs)),importance[idxs],align="center")
plt.yticks(range(len(idxs)),[feature_col[i] for i in idxs])
plt.xlabel("Random Forest Feature Importance")
plt.show()

# %% [markdown]
# ## Here we can se the importance of each feature, we can use this to reduce the dimentions of the DataFrame if needed.

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,roc_auc_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import pickle

# %%
y=df.Target.values
target_col="Target"

# %%
df=df.reset_index()

# %%
df.drop("index",inplace=True,axis=1)

# %%
df.head()
# Out:
#    feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 0    119.992    157.302     74.997    0.00784    0.00007    0.00370
# 1    122.400    148.650    113.819    0.00968    0.00008    0.00465
# 2    116.682    131.111    111.555    0.01050    0.00009    0.00544
# 3    116.676    137.871    111.366    0.00997    0.00009    0.00502
# 4    116.014    141.781    110.655    0.01284    0.00011    0.00655
#
#    feature 7  feature 8  feature 9  feature 10  ...  feature 14  feature 15  \
# 0    0.00554    0.01109    0.04374       0.426  ...     0.06545     0.02211
# 1    0.00696    0.01394    0.06134       0.626  ...     0.09403     0.01929
# 2    0.00781    0.01633    0.05233       0.482  ...     0.08270     0.01309
# 3    0.00698    0.01505    0.05492       0.517  ...     0.08771     0.01353
# 4    0.00908    0.01966    0.06425       0.584  ...     0.10470     0.01767
#
#    feature 16  feature 18  feature 19  feature 20  feature 21  feature 22  \
# ...

# %% [markdown]
# # Implementing Over Sampling due to data imbalance
# <img src="https://media.giphy.com/media/MEA9CV6F6lCVqo6Rni/giphy.gif" width=70%>

# %%
from imblearn.combine import SMOTETomek
from collections import Counter

# %%
df_up=df.drop("Target",axis=1)

# %%
df_up_val=df_up.values

# %%
smk=SMOTETomek(random_state=42)
X_res,y_res=smk.fit_resample(df_up_val,y)

# %%
X_res.shape,y_res.shape
# Out:
# ((290, 22), (290,))

# %%
print(f"Orignal Dataset Shape {Counter(y)}")
print(f"Resampled Dataset Shape {Counter(y_res)}")
# Out:
# Orignal Dataset Shape Counter({1: 147, 0: 48})
# Resampled Dataset Shape Counter({1: 145, 0: 145})

# %%
df_new=pd.concat([pd.DataFrame(X_res),pd.DataFrame(y_res)],axis=1)

# %%
feature_col.append("Target")
df_new.columns=feature_col

# %%
df_new.head()
# Out:
#    feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 0    119.992    157.302     74.997    0.00784    0.00007    0.00370
# 1    122.400    148.650    113.819    0.00968    0.00008    0.00465
# 2    116.682    131.111    111.555    0.01050    0.00009    0.00544
# 3    116.676    137.871    111.366    0.00997    0.00009    0.00502
# 4    116.014    141.781    110.655    0.01284    0.00011    0.00655
#
#    feature 7  feature 8  feature 9  feature 10  ...  feature 14  feature 15  \
# 0    0.00554    0.01109    0.04374       0.426  ...     0.06545     0.02211
# 1    0.00696    0.01394    0.06134       0.626  ...     0.09403     0.01929
# 2    0.00781    0.01633    0.05233       0.482  ...     0.08270     0.01309
# 3    0.00698    0.01505    0.05492       0.517  ...     0.08771     0.01353
# 4    0.00908    0.01966    0.06425       0.584  ...     0.10470     0.01767
#
#    feature 16  feature 18  feature 19  feature 20  feature 21  feature 22  \
# ...

# %% [markdown]
# # Machine Learning Model at work 🖥️
# <img src="https://media.giphy.com/media/pw2fLKLW3mgw/giphy.gif">

# %% [markdown]
# ## Using Logistic Regression

# %%
kf=model_selection.StratifiedKFold(n_splits=5)
log_acc=[]
for fold , (trn_,val_) in enumerate(kf.split(X=df_new,y=y_res)):
    
    X_train=df_new.loc[trn_,feature_col]
    y_train=df_new.loc[trn_,target_col]
    
    X_valid=df_new.loc[val_,feature_col]
    y_valid=df_new.loc[val_,target_col]
    
    log_scaler=RobustScaler()
    X_train=log_scaler.fit_transform(X_train)
    X_valid=log_scaler.transform(X_valid)

    clf=LogisticRegression()
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_valid)
    print(f"The fold is : {fold} : ")
    print(classification_report(y_valid,y_pred))
    acc=roc_auc_score(y_valid,y_pred)
    log_acc.append(acc)
    print(f"The AUC score for Fold {fold+1} : {acc}")
    #  Saving the model as well as the scaler for each fold
    with open(f"./Logistic/fold_{fold+1}.pkl","wb") as out_file:
        pickle.dump(clf,out_file)
    
    with open(f"./Logistic/scaler_{fold+1}.pkl","wb") as scaler_file:
        pickle.dump(log_scaler,scaler_file)
# Out:
# The fold is : 0 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58
#
# The AUC score for Fold 1 : 1.0
# The fold is : 1 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58
#
# The AUC score for Fold 2 : 1.0
# The fold is : 2 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
# ...

# %% [markdown]
# ## Using Support Vector Machine Classifier with Linear Kernel

# %%
kf=model_selection.StratifiedKFold(n_splits=5)
svm_acc=[]
for fold , (trn_,val_) in enumerate(kf.split(X=df_new,y=y_res)):
    
    X_train=df_new.loc[trn_,feature_col]
    y_train=df_new.loc[trn_,target_col]
    
    X_valid=df_new.loc[val_,feature_col]
    y_valid=df_new.loc[val_,target_col]
    
    svm_scaler=RobustScaler()
    X_train=svm_scaler.fit_transform(X_train)
    X_valid=svm_scaler.transform(X_valid)
    
    clf=SVC(kernel="linear")
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_valid)
    print(f"The fold is : {fold} : ")
    print(classification_report(y_valid,y_pred))
    acc=roc_auc_score(y_valid,y_pred)
    svm_acc.append(acc)
    print(f"The AUC Score for {fold+1} : {acc}")
    #  Saving the model as well as the scaler for each fold
    with open(f"./SVM/fold_{fold+1}.pkl","wb") as out_file:
        pickle.dump(clf,out_file)
    
    with open(f"./SVM/scaler_{fold+1}.pkl","wb") as scaler_file:
        pickle.dump(svm_scaler,scaler_file)
# Out:
# The fold is : 0 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58
#
# The AUC Score for 1 : 1.0
# The fold is : 1 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58
#
# The AUC Score for 2 : 1.0
# The fold is : 2 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
# ...

# %% [markdown]
# ## Using K-Nearest Neighbors

# %%
kf=model_selection.StratifiedKFold(n_splits=5)
knn_acc=[]
for fold , (trn_,val_) in enumerate(kf.split(X=df_new,y=y_res)):
    
    X_train=df_new.loc[trn_,feature_col]
    y_train=df_new.loc[trn_,target_col]
    
    X_valid=df_new.loc[val_,feature_col]
    y_valid=df_new.loc[val_,target_col]
    
    knn_scaler=RobustScaler()
    X_train=knn_scaler.fit_transform(X_train)
    X_valid=knn_scaler.transform(X_valid)
    
    clf=KNeighborsClassifier(n_neighbors=1)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_valid)
    print(f"The fold is : {fold} : ")
    print(classification_report(y_valid,y_pred))
    acc=roc_auc_score(y_valid,y_pred)
    knn_acc.append(acc)
    print(f"The AUC Score for {fold+1} : {acc}")
    #  Saving the model as well as the scaler for each fold
    with open(f"./KNN/fold_{fold+1}.pkl","wb") as out_file:
        pickle.dump(clf,out_file)
    
    with open(f"./KNN/scaler_{fold+1}.pkl","wb") as scaler_file:
        pickle.dump(knn_scaler,scaler_file)
# Out:
# The fold is : 0 :
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        29
#            1       1.00      0.90      0.95        29
#
#     accuracy                           0.95        58
#    macro avg       0.95      0.95      0.95        58
# weighted avg       0.95      0.95      0.95        58
#
# The AUC Score for 1 : 0.9482758620689655
# The fold is : 1 :
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95        29
#            1       0.93      0.97      0.95        29
#
#     accuracy                           0.95        58
#    macro avg       0.95      0.95      0.95        58
# weighted avg       0.95      0.95      0.95        58
#
# The AUC Score for 2 : 0.9482758620689656
# The fold is : 2 :
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        29
#            1       1.00      0.97      0.98        29
# ...

# %% [markdown]
# ## Using Random Forest Classifier

# %%
kf=model_selection.StratifiedKFold(n_splits=5)
rand_acc=[]
for fold , (trn_,val_) in enumerate(kf.split(X=df_new,y=y_res)):
    
    X_train=df_new.loc[trn_,feature_col]
    y_train=df_new.loc[trn_,target_col]
    
    X_valid=df_new.loc[val_,feature_col]
    y_valid=df_new.loc[val_,target_col]
    
    rf_scaler=RobustScaler()
    X_train=rf_scaler.fit_transform(X_train)
    X_valid=rf_scaler.transform(X_valid)
    
    clf=RandomForestClassifier(n_estimators=55,criterion="entropy")
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_valid)
    print(f"The fold is : {fold} : ")
    print(classification_report(y_valid,y_pred))
    acc=roc_auc_score(y_valid,y_pred)
    rand_acc.append(clf)
    print(f"The accuracy for {fold+1} : {acc}")
    #  Saving the model as well as the scaler for each fold
    with open(f"./RandomForest/fold_{fold+1}.pkl","wb") as out_file:
        pickle.dump(clf,out_file)
    
    with open(f"./RandomForest/scaler_{fold+1}.pkl","wb") as scaler_file:
        pickle.dump(rf_scaler,scaler_file)
# Out:
# The fold is : 0 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58
#
# The accuracy for 1 : 1.0
# The fold is : 1 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58
#
# The accuracy for 2 : 1.0
# The fold is : 2 :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#
# ...

# %%
def best_model():
    
    ## Taking the best models
    with open(f"./Logistic/fold_{np.argmax(log_acc)+1}.pkl","rb") as f:
        log_model = pickle.load(f)
    
    with open(f"./SVM/fold_{np.argmax(log_acc)+1}.pkl","rb") as f:
        svm_model = pickle.load(f)
    
    with open(f"./KNN/fold_{np.argmax(log_acc)+1}.pkl","rb") as f:
        knn_model = pickle.load(f)
    
    with open(f"./RandomForest/fold_{np.argmax(log_acc)+1}.pkl","rb") as f:
        rf_model = pickle.load(f)


    ## Getting the scaler for the same Best accuracy Fold
    with open(f"./Logistic/scaler_{np.argmax(log_acc)+1}.pkl","rb") as f:
        log_scaler = pickle.load(f)
    
    with open(f"./SVM/scaler_{np.argmax(log_acc)+1}.pkl","rb") as f:
        svm_scaler = pickle.load(f)
    
    with open(f"./KNN/scaler_{np.argmax(log_acc)+1}.pkl","rb") as f:
        knn_scaler = pickle.load(f)
    
    with open(f"./RandomForest/scaler_{np.argmax(log_acc)+1}.pkl","rb") as f:
        rf_scaler = pickle.load(f)

    ## Now testing on any part of the data by using test_train_split
    X_train,X_valid,y_train,y_valid=model_selection.train_test_split(df_new[feature_col],df_new["Target"],test_size=0.4)
    

    ## Transforming the Data
    X_valid_log=log_scaler.transform(X_valid)
    X_valid_svm=svm_scaler.transform(X_valid)
    X_valid_knn=knn_scaler.transform(X_valid)
    X_valid_rf=rf_scaler.transform(X_valid)

    ## Getting the prediction value for each model
    y_pred_log=log_model.predict(X_valid_log)
    y_pred_svm=svm_model.predict(X_valid_svm)
    y_pred_knn=knn_model.predict(X_valid_knn)
    y_pred_rf=rf_model.predict(X_valid_rf)

    print(f"Accuracy Score for the LogisticRegression() = {accuracy_score(y_pred_log,y_valid)*100}")
    print(f"Accuracy Score for the SVC(kernel='linear') = {accuracy_score(y_pred_svm,y_valid)*100}")
    print(f"Accuracy Score for the KNeighborsClassifier() = {accuracy_score(y_pred_knn,y_valid)*100}")
    print(f"Accuracy Score for the RandomForestClassifier() = {accuracy_score(y_pred_rf,y_valid)*100}")

# %%
best_model()
# Out:
# Accuracy Score for the LogisticRegression() = 100.0
# Accuracy Score for the SVC(kernel='linear') = 100.0
# Accuracy Score for the KNeighborsClassifier() = 100.0
# Accuracy Score for the RandomForestClassifier() = 100.0

# %% [markdown]
# # Reason for Choosing Random Forest
# -  👉The best model to use according to me will be Random Forest as It provides higher accuracy through cross validation. Random forest classifier will handle the missing values and maintain the accuracy of a large proportion of data. If there are more trees, it won't allow over-fitting trees in the model.
#
# -  👉As we are using AUC score as well for getting the accuracy along with Stratisfied Kfold Cross validation
# -  👉The higher the AUC, the better the performance of the model at distinguishing between the positive and negative classes. When AUC = 1, then the classifier is able to perfectly distinguish between all the Positive and the Negative class points correctly

# %% [markdown]
# <img src="https://media.giphy.com/media/icPn4EwqNpAsZQmInZ/giphy.gif" width=60%>

# %%
df_new.to_csv("parkinson_upsample.csv",index=False)

# %% [markdown]
# ## Please vist the deployed model : <a>https://share.streamlit.io/durgance/parkinsons_disease/main/app.py</a>
